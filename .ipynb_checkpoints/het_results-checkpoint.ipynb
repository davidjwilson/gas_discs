# %% [markdown]
# Formalising the HET results.

# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import os
import glob
from astropy.table import Table
from astropy.io import ascii
import astropy.units as u
import astropy.constants as const
from astropy.convolution import convolve, Box1DKernel
from scipy.optimize import leastsq
from scipy.interpolate import interp1d
from astropy.modeling import models, fitting
from astropy.time import Time

#matplotlib set up
# %matplotlib inline
from matplotlib import rcParams
rcParams["figure.figsize"] = (14, 5)
rcParams["font.size"] = 20

# %%
hetpath = '/media/david/2tb_ext_hd/hddata/het_gas/UT22-1-013/'

hetspecs = glob.glob('{}spectrum*d.fits'.format(hetpath)) #just the red arm
# hetspecs

# %%
fits.getheader(hetspecs[1])
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -64 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 2064
# NAXIS2  =                    6
# EXTEND  =                    T
# DATE    = '2021-12-16T05:49:17.617484'
# DATE-OBS= '2021-12-16'
# TELESCOP= 'het     '
# INSTRUME= 'lrs2    '
# OBJECT  = 'WDJ0147+2339_066_W'
# OBSERVER= ''
# TELRA   = '+01:48:58.7'
# TELDEC  = '+23:44:38.6'
# TELEQNOX=                 2000
# PARANGLE=           249.906573
# STRUCTAZ=           268.189327
# STRUCTEL=            55.068647
# HA      = '+02:36:10.7'
# ZD      =            34.931353
# AIRMASS =     1.21975217780848
# X_STRT  =            24.969248
# Y_STRT  =    71.65359599999999
# Z_STRT  =            -0.814953
# RHO_STRT=            -0.153512
# THE_STRT=             0.303762
# PHI_STRT=             0.107354
# RHO_OFFS=            -999999.9
# TCS_UP  =                    T
# TRAJID  =                  323
# TRAJRA  =             1.796014
# TRAJDEC =            23.634933
# TRAJEQ  =                 2000
# TRAJCRA =             1.796014
# TRAJCDEC=            23.634933
# TRAJCEQ =                 2000
# TRAJDIR = 'West    '
# TRAJOBJ = 'WDJ0147+2339'
# QDEC    = '+23:39:43.60'
# QEPOCH  =                 2000
# QEQUINOX=                 2000
# QIDX    =                   36
# QIFU    = ''
# QOBJECT = 'WDJ0147+2339'
# QPMDEC  =                    0
# QPMRA   =                    0
# QPROG   = 'UT22-1-013'
# QRA     = '01:47:54.82'
# DATAFORM= 'CAMRA   '
# UT      = '05:40:51.532'
# ST      = '+01:09:25.0'
# MJD     =     59564.2367075575
# HOSTCOMP= 'lrs2    '
# HOSTOPS = 'Linux 2.6.32-754.30.2.el6.x86_64'
# PROGRAM = 'camra_server-r12750 2021-09-30T14:47:58.000'
# NCCDS   =                    1
# CCDSUM  = '1 1     '
# HWSUM   = '1 1     '
# CCDSIZE = '[1:2064,1:2064]'
# OPERATOR= ''
# OBSID   =                   10
# RECIPE  = '/usr/local/bin/vlexp -B -i lrs2 -pobj WDJ0147+2339_066_W -texp 450.0'
# OBSERVAT= 'MCDONALD'
# REXPTIME=                  450
# PEXPTIME=         465.10735766
# DARKTIME=        504.913607614
# READTIME=         37.795300061
# IMAGETYP= 'sci     '
# SUBORDIN=                    F
# UPTIME  =     545749.894777781
# EXPTIME =        456.993551872
# PFIPUTC = '1639633757.028385591'
# DITHER  =                    1
# FPASHUTR= 'Closed  '
# FILTEREN=                    1
# FILTEREX=                    1
# ENWAPOS = 'Clear   '
# EXWAPOS = 'Clear   '
# LIGHTBNK= 'Slider A'
# LIGHTGDE= 'Blue    '
# FCUHEAD = 'Retracted'
# FCUEXPTM=                  1.8
# LAMP    = 'Hg      '
# SLIDER  = 'A       '
# LIDLDLS = '20170401'
# LIDHGA  = '20170401'
# LIDCDA  = '20170401'
# LIDFEARA= '20170401'
# LIDKRA  = '20170401'
# LIDCDB  = '20170401'
# LIDNEB  = '20170401'
# LIDHPFB = '20180419'
# LIDTHARB= '20170401'
# LIDQTHB = '20170401'
# WEATDATE= '2021-12-16T05:40:51.987'
# AMBTEMP =     15.5722222222222
# HUMIDITY=               21.087
# DEWPOINT=    -4.68777777777778
# BAROMPRE=        -99898.450425
# WINDDIR =               239.25
# WINDSPD =               21.251
# DUST1_0 =                 2123
# DUST0_3 =                36188
# WEAT_UP =                    T
# MUXID   =                    0
# MICROCOD= 'tim_0026.lod'
# MCODMD5 = '34f4c77ce113308fe131e06ea0cf4f6c'
# READELAY=                    0
# CONTID  = 'S/N 0100'
# CHCONTID=              -999999
# TIMING  = 'ARC1215  REV 2A   28/06/12 S/N 0100 U1R2A.0  U48R2A.0'
# CD      = 'ARC13    REV 1V   26/07/12 S/N 0096 U49R1V.0'
# VIDEO   = 'ARC14    REV 1V   05/12/13 S/N 0096 U9R1V.0'
# PC      = 'ARC17    REV 1V   17/07/12 S/N 0100 U1R1V.0'
# FLEX    = 'ARCVFLEX REV 3    01/09/12 S/N 0066 DEFAULT'
# SSA     = '121     '
# CRYOTEMP=    -185.601135092787
# CONTTEMP=            -999999.9
# PRESSURE=             7.15E-07
# MBAROK  =                    F
# SPECID  =                  502
# IFUID   = '7002    '
# IFUSLOT =                   66
# CCDPOS  = 'L       '
# DETECTOR=                15609
# DETTEMP =    -109.995452322066
# SETPOINT=                 -110
# SERVOPWR=           1.27155416
# S1_HI   =                  4.5
# S1_LO   =                 -4.5
# P1_HI   =                    2
# P1_LO   =                   -8
# S2_HI   =                  4.5
# S2_LO   =                 -4.5
# P2_HI   =                    2
# P2_LO   =                   -8
# S3_HI   =                  4.5
# S3_LO   =                 -4.5
# P3_HI   =                  3.5
# P3_LO   =                 -6.5
# SW_HI   =                    4
# SW_LO   =                   -4
# RG_HI   =                    6
# RH_LO   =                   -2
# VOD_U   =                   26
# VOD_L   =                   26
# VOG     =                  0.5
# VRD     =                   15
# CCDHALF = 'L       '
# AMPLIFIE= 'LL      '
# AMPNAME = 'LL      '
# GAIN    =    0.876999974250793
# RDNOISE =     2.79999995231628
# BIASSET =                 1920
# BIASTRGT=                 2000
# REPEAT  =                    F
# DWAVE   =   0.9452253999033928
# WAVE0   =               6450.0
# WAVESOL = 'WAVE0 + DWAVE * linspace(0, NAXIS1)'
# WAVEUNIT= 'A       '
# SOURCEX =  -0.5928769294409586
# SOURCEY =   0.6189892615681301
# SEEING  =    2.679239017441336
# MILLUM  =    476212.7412702702
# THROUGHP=   0.7351256486486486
# FLUXUNIT= 'ergs/s/cm2/A'
# ROW1    = 'wavelength'
# ROW2    = 'F_lambda'
# ROW3    = 'Sky_lambda'
# ROW4    = 'e_F_lambda'
# ROW5    = 'e_Sky_lambda'
# ROW6    = 'response'

# %%
stars = []
for spec in hetspecs:
    data = fits.getdata(spec)
    star = fits.getheader(spec)['QOBJECT']
    # print(star)
    stars.append(star)
stars = np.unique(stars)
print(stars)
# Out:
# ['WDJ0147+2339' 'WDJ0347+1624' 'WDJ0845+2257' 'WDJ0846+5703'
#  'WDJ1622+5840']

# %% [markdown]
# Group spectra by star and date. Coadd spectra from the same date, and measure eqivalent widths.

# %%
def wavelength_edges(w):
    """
    Calulates w0 and w1
    """
    diff = np.diff(w)
    diff0 = np.concatenate((np.array([diff[0]]), diff)) #adds an extravalue to make len(diff) = len(w)
    diff1 = np.concatenate((diff, np.array([diff[-1]]))) #adds an extravalue to make len(diff) = len(w)
    w0 = w - diff0/2.
    w1 = w + diff1/2.
    return w0, w1

def spectra_adder(f_array, e_array, rcs = True):
    """
    Returns a variance-weighted coadd with standard error of the weighted mean (variance weights, scale corrected).
    f_array and e_arrays are collections of flux and error arrays, which should have the same lenth and wavelength scale
    """
    weights = 1 / (e_array**2)
    flux = np.average(f_array, axis =0, weights = weights)
    var = 1 / np.sum(weights, axis=0)
    if rcs:
        rcs = np.sum((((flux - f_array)**2) * weights), axis=0) / (len(f_array)-1) #reduced chi-squared
        error = (var * rcs)**0.5
    else:
        error = var**0.5
    return flux, error

def make_plot_spec(w, f, e, triplet_edges, waveband=[8400, 8750], smooth=10): #cuts spectrum down to the bit to plot
    """
    Normalises the spectrum around the Caii lines. Waveband is the strech of spectrum to return. Triplet gives the regions to include when normalising.
    """
    fitter = fitting.LinearLSQFitter()

    tripmask = (w > triplet_edges[0]) & (w < triplet_edges[1]) | (w > triplet_edges[2]) & (w < triplet_edges[3]) | (w > triplet_edges[4]) & (w < triplet_edges[5]) | (w > triplet_edges[6]) & (w < triplet_edges[7]) | (w > triplet_edges[8]) & (w < triplet_edges[9])   
    w1, f1 = w[bandmask], f[]
    n_init = models.Polynomial1D(3)
    n_fit = fitter(n_init, w1, f1)
    #mask = (w > 8450) & (w < 8700)
    nf = f/n_fit(w)
    ne = e/n_fit(w)
    if smooth == 0:
        smooth = 1
    nf = convolve(nf,Box1DKernel(smooth))
    ne = convolve(ne,Box1DKernel(smooth))/smooth**0.5
    bandmask = (w >= waveband[0]) & (w < waveband[1])
    w1, f1, e1 = w[mask2], nf[mask2], ne[mask2]
    return w1,f1, e1

# %%
smooth = 4
for star in stars:
    print(star)
    dates = []
    for spec in hetspecs:
        hdr = fits.getheader(spec)
        if hdr['QOBJECT'] == star:
            dates.append(hdr['DATE-OBS'])
    dates = np.unique(dates)
    for date in dates:
        print(date)
        fs  = [] #arrays to put fluxes and errors in to coadd, wavelength grid is the same for each spectrum
        es = []
        for spec in hetspecs:
            hdr = fits.getheader(spec)
            if hdr['DATE-OBS'] == date and hdr['QOBJECT'] == star and hdr['WAVE0'] > 8000:
                data = fits.getdata(spec)
                w, fi, ei = data[0], data[1], data[3]
                fs.append(fi)
                es.append(ei)
        if len(np.array(fs)) >1:
            f, e = spectra_adder(np.array(fs), np.array(es), rcs = True)
        else:
            f, e = fi, ei
            
        mask = (w > 8400) & (w < 8750)
        plt.plot(w[mask],f[mask])
        # plt.plot(w[mask], e[mask])
                # f = convolve(f,Box1DKernel(smooth))
                # plt.step(w,f, alpha =0.5)
    plt.show()
# Out:
# WDJ0147+2339
# 2021-12-16
# 2022-01-03
# 2022-01-17
# WDJ0347+1624
# 2022-02-09
# 2022-02-11
# 2022-02-21
# WDJ0845+2257
# 2021-12-29
# 2022-01-23
# 2022-02-10
# 2022-02-27
# WDJ0846+5703
# 2022-02-10
# 2022-02-28
# 2022-03-11
# WDJ1622+5840
# 2022-02-13
